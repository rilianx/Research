# %%
# !pip install paramiko
# Out:
# Requirement already satisfied: paramiko in d:\programar\lib\site-packages (2.7.1)
# Requirement already satisfied: pynacl>=1.0.1 in d:\programar\lib\site-packages (from paramiko) (1.4.0)
# Requirement already satisfied: cryptography>=2.5 in d:\programar\lib\site-packages (from paramiko) (2.9.2)
# Requirement already satisfied: bcrypt>=3.1.3 in d:\programar\lib\site-packages (from paramiko) (3.1.7)
# Requirement already satisfied: cffi>=1.4.1 in d:\programar\lib\site-packages (from pynacl>=1.0.1->paramiko) (1.14.0)
# Requirement already satisfied: six in d:\programar\lib\site-packages (from pynacl>=1.0.1->paramiko) (1.15.0)
# Requirement already satisfied: pycparser in d:\programar\lib\site-packages (from cffi>=1.4.1->pynacl>=1.0.1->paramiko) (2.20)

# %% [markdown]
# Conexión al server mediante SSH

# %%
import ibex
ssh = ibex.connect("158.251.88.197")
# Out:
# Cargando ibex...

# %% [markdown]
# Se obtienen las instancias de prueba

# %%
ibex.get_instances(ssh)
# Out:
# binh.txt cf3-3.txt cf3-5.txt ctp1-3.txt ctp1-5.txt ctp2-3.txt ctp2-5.txt ctp6-3.txt ctp6-4.txt ctp7-4.txt ctp7-5.txt kim.txt mop-10.txt mop-13.txt mop-7.txt nbi.txt osy.txt sr.txt tan.txt test.txt wb.txt

# %% [markdown]
# Se obtienen las soluciones

# %%
import importlib
import matplotlib.pyplot as plt
import numpy as np
importlib.reload(ibex) #recarga el archivo en caso de modificación

# %matplotlib inline

instance = "binh.txt"
prec = 10 #precisión para el solver

#Aquí se llama al solver
y1, y2 = ibex.solve(ssh, instance, prec=prec)

#plot
plt.plot(y1, y2, 'ro', y1, y2, 'g-')
plt.show()
# Out:
# Cargando ibex...

# %% [markdown]
# Se reducen los puntos que tienen coordenadas iguales

# %%
import importlib
import matplotlib.pyplot as plt
import numpy as np

importlib.reload(ibex)

# %matplotlib inline

instance = "binh.txt"
prec = 10 #presicion para el solver

#se llama al solver
y1, y2 = ibex.solve(ssh, instance, prec=prec)

#se llama a funcion que reduce puntos iguales
ibex.filtrado_puntos(y1,y2)

fig2 = plt.figure("grafica 2")
plt.plot(y1, y2, 'ro',y1, y2, 'b-')
plt.show
# Out:
# Cargando ibex...
# [ 6.42844019  6.42844036  7.57827915  7.57827915  7.57827933 13.17612516
#  13.17612516 13.17612542 13.42600928 13.42600928 13.65367802 14.95101709
#  14.95101709 16.32924953 24.3        24.3        29.53864072 32.15926241
#  32.15926241 39.11398333 49.3259402  53.70403711 53.70403711 53.70403711
#  53.70403711 56.06655284 59.47396726 59.47396726 82.84563164 97.2
#  97.2       ] [38.92992563 38.92992563 38.26548172 38.13023258 38.13023258 34.91188471
#  27.62748998 27.62748998 27.53417825 27.44916209 27.44916209 26.9647092
#  26.45004908 26.45004908 23.47360816 21.51739278 21.51739278 20.53879915
#  17.9417644  17.9417644  14.12841127 11.61132893 11.61132893 11.61132883
#  11.61132893 11.61132892 10.33893082 10.33893072 10.33893072  5.18478567
#   5.18478557]
# Se filtraron 10 puntos
# [ 6.  8. 13. 13. 13. 14. 15. 15. 16. 24. 24. 30. 32. 32. 39. 49. 54. 56.
#  59. 83. 97.] [39. 38. 35. 28. 27. 27. 27. 26. 26. 23. 22. 22. 21. 18. 18. 14. 12. 12.
#  10. 10.  5.]
# <function matplotlib.pyplot.show(*args, **kw)>

# %% [markdown]
# Se calcula el hipervolumen de la region dominada

# %%
import importlib
import matplotlib.pyplot as plt
import numpy as np

importlib.reload(ibex)

# %matplotlib inline

instance = "binh.txt"
prec = 10 #presicion para el solver

#se llama al solver
y1, y2 = ibex.solve(ssh, instance, prec=prec)

#se llama a la funcion para calcular el hipervolumen
ibex.hipervolumen(y1,y2)

plt.plot(y1, y2, 'ro', y1, y2, 'g-')
plt.show()
# Out:
# Cargando ibex...
# El hipervolumen de la grafica es de 2339.5

# %% [markdown]
# Se calcula la menor area de las soluciones y a que punto corresponde

# %%
import importlib
import matplotlib.pyplot as plt
import numpy as np

importlib.reload(ibex)

# %matplotlib inline

instance = "binh.txt"
prec = 10 #presicion para el solver

#se llama al solver
y1, y2 = ibex.solve(ssh, instance, prec=prec)

#aqui se llama a la funcion para que calcule la menor area y a que punto corresponde
ibex.menorArea(y1,y2)
# Out:
# Cargando ibex...
# Se calcula la menor area
# El menor area es:  0.0 y corresponde al punto 3
# c:\Users\Stone\Desktop\nuevo\funcion.py:117: RuntimeWarning: divide by zero encountered in double_scalars
#   m2 = (y2[pto+2]-y2[pto+1])/(y1[pto+2]-y1[pto+1])
# c:\Users\Stone\Desktop\nuevo\funcion.py:238: RuntimeWarning: divide by zero encountered in double_scalars
#   m = (z[1]-x[1])/(z[0]-x[0])
# c:\Users\Stone\Desktop\nuevo\funcion.py:240: RuntimeWarning: invalid value encountered in double_scalars
#   valor = (m*y[0]) + b

# %% [markdown]
# Se calcula si el punto se encuentra sobre o debajo el segmento formado entre el punto anterior y el siguiente

# %%
import importlib
import matplotlib.pyplot as plt
import numpy as np

importlib.reload(ibex)

# %matplotlib inline

instance = "binh.txt"
prec = 10 #presicion para el solver

#se llama al solver
y1, y2 = ibex.solve(ssh, instance, prec=prec)

#se llama a la funcion la cual ve si el punto esta por sobre o debajo el segmento
h1,h2 = ibex.posicion_punto(y1,y2,4)

#se grafica para situar visualmente el punto
plt.plot(h1, h2, 'ro', h1, h2, 'g-')
plt.show()
# Out:
# Cargando ibex...
# Con el punto anteriormente señalado se obtiene un subconjunto de puntos pertenecientes al punto anterior, el que se selecciono y el siguiente
#
# Luego con los 3 puntos se calcula si el punto esta sobre o debajo el segmento formado entre los puntos de los extremos, arrojando 2 posibles casos:
#
# ~ El punto esta sobre el segmento
# ~ El punto esta por debajo del segmento
#
# El punto 4 se encuentra sobre el segmento

# %% [markdown]
# Se elimina un punto del conjunto de soluciones

# %%
import importlib
import matplotlib.pyplot as plt
import numpy as np

importlib.reload(ibex)

# %matplotlib inline

instance = "binh.txt"
prec = 10 #presicion para el solver

#se llama al solver
y1, y2 = ibex.solve(ssh, instance, prec=prec)

#Se llama a la funcion la cual elimina el punto señalado
y1,y2 = ibex.elimina_punto(y1,y2,4)

#se grafican los puntos, si el punto eliminado estaba cerca de otro en algunos casos no se logra apreciar el cambio
fig2 = plt.figure("grafica 2")
plt.plot(y1, y2, 'ro',y1, y2, 'b-')
plt.show
# Out:
# Cargando ibex...
# [ 6.  8. 13. 13. 13. 14. 15. 15. 16. 24. 24. 30. 32. 32. 39. 49. 54. 56.
#  59. 83. 97.] [39. 38. 35. 28. 27. 27. 27. 26. 26. 23. 22. 22. 21. 18. 18. 14. 12. 12.
#  10. 10.  5.]
# El punto a eliminar será el 13.0 28.0
# el hipervolumen total inicial es de 2339.5
# el hipervolumen final es de 2339.0
# c:\Users\Stone\Desktop\nuevo\funcion.py:117: RuntimeWarning: divide by zero encountered in double_scalars
#   m2 = (y2[pto+2]-y2[pto+1])/(y1[pto+2]-y1[pto+1])
# c:\Users\Stone\Desktop\nuevo\funcion.py:238: RuntimeWarning: divide by zero encountered in double_scalars
#   m = (z[1]-x[1])/(z[0]-x[0])
# c:\Users\Stone\Desktop\nuevo\funcion.py:240: RuntimeWarning: invalid value encountered in double_scalars
#   valor = (m*y[0]) + b
# c:\Users\Stone\Desktop\nuevo\funcion.py:15: RuntimeWarning: divide by zero encountered in double_scalars
#   m2 = (z[1]-y[1])/(z[0]-y[0])
# <function matplotlib.pyplot.show(*args, **kw)>

# %% [markdown]
# Se eliminan una serie de puntos del conjunto de soluciones

# %%
import importlib
import matplotlib.pyplot as plt
import numpy as np

importlib.reload(ibex)

# %matplotlib inline

instance = "binh.txt"
prec = 10 #presicion para el solver

#se llama al solver
y1, y2 = ibex.solve(ssh, instance, prec=prec)

#se llama a la funcion para eliminar una cierta cantidad de puntos
y1, y2 = ibex.reduc_puntos(y1,y2,14)

#se vuelven a graficar las soluciones con los puntos ya eliminados
plt.plot(y1, y2, 'go',y1, y2, 'b-')
plt.show
# Out:
# Cargando ibex...
# el hipervolumen inicial es de 2339.5
# El menor area es:  0.0 y corresponde al punto 3
#
# El menor area es:  0.0 y corresponde al punto 5
#
# El menor area es:  0.0 y corresponde al punto 13
#
# El menor area es:  0.5 y corresponde al punto 5
#
# El menor area es:  0.833333333333333 y corresponde al punto 5
#
# El menor area es:  1.0 y corresponde al punto 8
#
# El menor area es:  1.75 y corresponde al punto 2
#
# El menor area es:  3.0 y corresponde al punto 5
#
# El menor area es:  4.25 y corresponde al punto 2
#
# El menor area es:  6.0 y corresponde al punto 7
#
# El menor area es:  7.5 y corresponde al punto 4
#
# El menor area es:  14.0 y corresponde al punto 4
#
# El menor area es:  24.0 y corresponde al punto 6
#
# El menor area es:  25.235294117647072 y corresponde al punto 4
#
# el hipervolumen final es de 2138.75
# c:\Users\Stone\Desktop\nuevo\funcion.py:117: RuntimeWarning: divide by zero encountered in double_scalars
#   m2 = (y2[pto+2]-y2[pto+1])/(y1[pto+2]-y1[pto+1])
# c:\Users\Stone\Desktop\nuevo\funcion.py:238: RuntimeWarning: divide by zero encountered in double_scalars
#   m = (z[1]-x[1])/(z[0]-x[0])
# c:\Users\Stone\Desktop\nuevo\funcion.py:240: RuntimeWarning: invalid value encountered in double_scalars
#   valor = (m*y[0]) + b
# c:\Users\Stone\Desktop\nuevo\funcion.py:15: RuntimeWarning: divide by zero encountered in double_scalars
#   m2 = (z[1]-y[1])/(z[0]-y[0])
# <function matplotlib.pyplot.show(*args, **kw)>
